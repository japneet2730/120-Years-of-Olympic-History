# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_athlete_events.csv')
df
# Out:
#                             Name Sex  Age  Height  Weight            Team  \
# 0                      A Dijiang   M   24     180    80.0           China
# 1                       A Lamusi   M   23     170    60.0           China
# 2            Gunnar Nielsen Aaby   M   24     175    70.0         Denmark
# 3           Edgar Lindenau Aabye   M   34     175    70.0  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F   21     185    82.0     Netherlands
# ...                          ...  ..  ...     ...     ...             ...
# 269726                Andrzej ya   M   29     179    89.0        Poland-1
# 269727                  Piotr ya   M   27     176    59.0          Poland
# 269728                  Piotr ya   M   27     176    59.0          Poland
# 269729        Tomasz Ireneusz ya   M   30     185    96.0          Poland
# 269730        Tomasz Ireneusz ya   M   34     185    96.0          Poland
#
#         NOC        Games  Year  Season            City          Sport  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1 = LabelEncoder()
le1.fit(df['Sex'])
df['Sex'] = le1.transform(df['Sex'])

# %%
le2 = LabelEncoder()
le2.fit(df['NOC'])
df['NOC'] = le2.transform(df['NOC'])

# %%
le3 = LabelEncoder()
le3.fit(df['Season'])
df['Season'] = le3.transform(df['Season'])

# %%
le4 = LabelEncoder()
le4.fit(df['Sport'])
df['Sport'] = le4.transform(df['Sport'])

# %%
df
# Out:
#                             Name  Sex  Age  Height  Weight            Team  \
# 0                      A Dijiang    1   24     180    80.0           China
# 1                       A Lamusi    1   23     170    60.0           China
# 2            Gunnar Nielsen Aaby    1   24     175    70.0         Denmark
# 3           Edgar Lindenau Aabye    1   34     175    70.0  Denmark/Sweden
# 4       Christine Jacoba Aaftink    0   21     185    82.0     Netherlands
# ...                          ...  ...  ...     ...     ...             ...
# 269726                Andrzej ya    1   29     179    89.0        Poland-1
# 269727                  Piotr ya    1   27     176    59.0          Poland
# 269728                  Piotr ya    1   27     176    59.0          Poland
# 269729        Tomasz Ireneusz ya    1   30     185    96.0          Poland
# 269730        Tomasz Ireneusz ya    1   34     185    96.0          Poland
#
#         NOC        Games  Year  Season            City  Sport  \
# ...

# %%
x = df[['Sex','Age','Height','Weight','NOC','Season','Sport']]
y = df['Medal']

# %%
x
# Out:
#         Sex  Age  Height  Weight  NOC  Season  Sport
# 0         1   24     180    80.0   41       0      8
# 1         1   23     170    60.0   41       0     32
# 2         1   24     175    70.0   55       0     24
# 3         1   34     175    70.0   55       0     61
# 4         0   21     185    82.0  145       1     53
# ...     ...  ...     ...     ...  ...     ...    ...
# 269726    1   29     179    89.0  162       1     34
# 269727    1   27     176    59.0  162       1     50
# 269728    1   27     176    59.0  162       1     50
# 269729    1   30     185    96.0  162       1     12
# 269730    1   34     185    96.0  162       1     12
#
# [269731 rows x 7 columns]

# %%
y
# Out:
# 0           No
# 1           No
# 2           No
# 3         Gold
# 4           No
#           ...
# 269726      No
# 269727      No
# 269728      No
# 269729      No
# 269730      No
# Name: Medal, Length: 269731, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
x_train
# Out:
#         Sex  Age  Height  Weight  NOC  Season  Sport
# 161012    1   24     175    70.0   81       0     63
# 199403    1   35     175    70.0   13       0      4
# 216503    1   22     182    77.0   74       0      5
# 97514     1   26     175    70.0   69       0     22
# 243478    1   24     172    74.0  207       0     65
# ...     ...  ...     ...     ...  ...     ...    ...
# 119879    1   24     190    92.0  193       1     34
# 259178    1   20     184    79.0  193       1     11
# 131932    1   22     183    82.0   63       0     14
# 146867    1   24     175    70.0   19       0     63
# 121958    0   24     162    60.0   79       0      5
#
# [215784 rows x 7 columns]

# %%
y_train
# Out:
# 161012    No
# 199403    No
# 216503    No
# 97514     No
# 243478    No
#           ..
# 119879    No
# 259178    No
# 131932    No
# 146867    No
# 121958    No
# Name: Medal, Length: 215784, dtype: object

# %%
x_test
# Out:
#         Sex  Age  Height  Weight  NOC  Season  Sport
# 81100     1   24     175    70.0  210       0     27
# 123998    1   28     179    65.0  104       0      5
# 31114     1   33     168    72.0  130       0     21
# 248008    1   28     175    70.0   19       0     22
# 1541      1   25     171    65.0  193       0     19
# ...     ...  ...     ...     ...  ...     ...    ...
# 249326    0   23     156    51.0  169       0     27
# 99734     1   21     173    68.0  122       0     27
# 5926      1   21     182    68.0   63       0     24
# 123268    1   20     177    82.0   30       0     46
# 196345    1   34     175    70.0  199       0     58
#
# [53947 rows x 7 columns]

# %%
y_test
# Out:
# 81100       No
# 123998      No
# 31114       No
# 248008      No
# 1541        No
#           ...
# 249326      No
# 99734       No
# 5926      Gold
# 123268      No
# 196345      No
# Name: Medal, Length: 53947, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Japneet\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(pred,y_test)
acc
# Out:
# 0.8547833985207703

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mod = DecisionTreeClassifier()

# %%
mod.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pre1 = mod.predict(x_test)
pre1
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
sc1 = accuracy_score(pre1,y_test)
sc1
# Out:
# 0.8031030455817747

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
mod2 = RandomForestClassifier()

# %%
mod2.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pre2 = mod2.predict(x_test)
pre2
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
sc2 = accuracy_score(pre2,y_test)
sc2
# Out:
# 0.8452369918623834
